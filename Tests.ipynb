# %%
import cptac

# %%
br = cptac.Brca()
en = cptac.Ucec()
ov = cptac.Ov()
cc = cptac.Ccrcc()

# %%
cc.list_data_sources()
# Out:
#           Data type  Available sources
# 0          clinical               mssm
# 1        proteomics              umich
# 2  somatic_mutation  harmonized, washu
# 3   transcriptomics  bcm, broad, washu

# %%
en.get_somatic_mutation('harmonized')
# Out:
# Name           Gene           Mutation  Location  Entrez_Gene_Id NCBI_Build  \
# Patient_ID
# C3L-00006     CPEB3  Missense_Mutation   p.R595C         22849.0       hg38
# C3L-00006    SHANK2  Missense_Mutation  p.S1692R         22941.0       hg38
# C3L-00006      CTTN  Missense_Mutation   p.R119C          2017.0       hg38
# C3L-00006     TPCN2  Missense_Mutation   p.V572I        219931.0       hg38
# C3L-00006   PITPNM1             Silent   p.R478R          9600.0       hg38
# ...             ...                ...       ...             ...        ...
# C3N-01825     ERBB3  Missense_Mutation  p.P1007S          2065.0       hg38
# C3N-01825     ABTB2  Missense_Mutation   p.G533E         25841.0       hg38
# C3N-01825      HPS5  Missense_Mutation    p.R44W         11234.0       hg38
# C3N-01825    PWWP2B  Missense_Mutation   p.E402K        170394.0       hg38
# C3N-01825     STUB1  Missense_Mutation   p.R146H         10273.0       hg38
#
# ...

# %%
en.get_somatic_mutation('washu')
# Out:
# ...
# Name              Gene           Mutation       Location  Entrez_Gene_Id  \
# Patient_ID
# C3L-00006   FO538757.2  Missense_Mutation         p.S49G               0
# C3L-00006        MXRA8    Frame_Shift_Del  p.R301Gfs*107               0
# C3L-00006         GNB1  Missense_Mutation        p.R314C               0
# C3L-00006        RPL22  Missense_Mutation         p.V72M               0
# C3L-00006        CASZ1  Missense_Mutation        p.R233Q               0
# ...                ...                ...            ...             ...
# C3N-01825     KRTAP4-7  Missense_Mutation        p.L148V               0
# C3N-01825     KRTAP4-8  Missense_Mutation         p.T63S               0
# C3N-01825    SERPINB12  Missense_Mutation         p.R43H               0
# C3N-01825        FCHO1  Missense_Mutation        p.E812K               0
# C3N-01825       ZNF729  Missense_Mutation        p.S864T               0
#
# Name       Center NCBI_Build Chromosome  Start_Position  End_Position Strand  \
# ...

# %%
ov.get_somatic_mutation('washu')
# Out:
# ...
# Name           Gene           Mutation     Location  Entrez_Gene_Id Center  \
# Patient_ID
# 01OV007     COL21A1             Silent       p.L14L               0      .
# 01OV007      GABRR3    Frame_Shift_Del  p.F104Lfs*3               0      .
# 01OV007       ABTB1             Silent       p.R61R               0      .
# 01OV007     SLC35G2  Missense_Mutation      p.K400R               0      .
# 01OV007      DZIP1L  Missense_Mutation      p.K645E               0      .
# ...             ...                ...          ...             ...    ...
# 26OV013     MRGPRX2  Missense_Mutation      p.G236S               0      .
# 26OV013       OR4S1             Silent       p.V43V               0      .
# 26OV013       OR8H2             Silent       p.L18L               0      .
# 26OV013       ADCY1  Missense_Mutation      p.G487D               0      .
# 26OV013      SQSTM1  Missense_Mutation      p.A426V               0      .
#
# ...

# %%
cc.get_somatic_mutation('washu')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/n2/95tlbmw5173fm8yjh4ffxggr0000gn/T/ipykernel_27754/4054623382.py in <module>
# ----> 1 cc.get_somatic_mutation('washu')
#
# ~/Documents/cptac/cptac/cancers/cancer.py in get_somatic_mutation(self, source, tissue_type, imputed)
#     199     def get_somatic_mutation(self, source: str=None, tissue_type: str="both", imputed: bool=False) -> pd.DataFrame:
#     200         """Get the somatic mutation dataframe from the specified data source."""
# --> 201         return self.get_dataframe("somatic_mutation", source, tissue_type, imputed=imputed)
#     202
#     203     def get_somatic_mutation_binary(self, source: str=None) -> pd.DataFrame:
#
# ~/Documents/cptac/cptac/cancers/cancer.py in get_dataframe(self, name, source, tissue_type, imputed)
# ...
