# %%
import cptac

# %%
br = cptac.Brca()

# %%
br.list_data_sources()
# Out:
#           Data type  Available sources
# 0          clinical               mssm
# 1        proteomics              umich
# 2  somatic_mutation  harmonized, washu
# 3   transcriptomics  bcm, broad, washu

# %%
br.get_transcriptomics('broad')
# Out:
# Polars found a filename. Ensure you pass a path to the file instead of a python file object when possible for best performance.
# Name                        A1BG                                        \
# Transcript_ID  ENST00000263100.8  ENST00000595014.1  ENST00000596924.1
# Database_ID   ENSG00000121410.12 ENSG00000121410.12 ENSG00000121410.12
# Patient_ID
# 01BR001                      0.0               0.06               0.15
# 01BR008                      0.0               0.09               0.06
# 01BR009                      0.0               0.13               0.47
# 01BR010                      0.0               0.16               0.25
# 01BR015                      0.0               0.04               0.39
# ...                          ...                ...                ...
# 21BR010                      0.0               0.17               0.20
# 22BR005                      0.0               0.03               0.21
# ...
