# %% [markdown]
# # Dataframe join examples
#
# In this use case, we provide several examples of how to use the built-in <code>cptac</code> functions for joining different dataframes.

# %%
import cptac
en = cptac.Endometrial()

# %% [markdown]
# ## General format
#
# In all of the join functions, you specify the dataframes you want to join by passing their names to the appropriate parameters in the function call. The function will automatically check that the dataframes whose names you provided are valid for the join function, and print an error message if they aren't.
#
# Whenever a column from an -omics dataframe is included in a joined table, the name of the -omics dataframe it came from is joined to the column header, to avoid confusion.
#
# If you wish to only include particular columns in the join, pass them to the appropriate parameters in the join function. All such parameters will accept either a single column name as a string, or a list of column name strings. In this use case, we will usually only select specific columns for readability, but you could select the whole dataframe in all these cases, except for the mutations dataframe.
#
# The join functions use logic analogous to an SQL INNER JOIN.

# %% [markdown]
# ## <code>join_omics_to_omics</code>
#
# The <code>join_omics_to_omics</code> function joins two -omics dataframes to each other:

# %%
prot_and_phos = en.join_omics_to_omics(df1_name="proteomics", df2_name="phosphoproteomics")
prot_and_phos.head()
# Out:
#            A1BG_proteomics  A2M_proteomics  A2ML1_proteomics  \
# Sample_ID
# S001                -1.180         -0.8630            -0.802
# S002                -0.685         -1.0700            -0.684
# S003                -0.528         -1.3200             0.435
# S005                -1.670         -1.1900            -0.443
# S006                -0.374         -0.0206            -0.537
#
#            A4GALT_proteomics  AAAS_proteomics  AACS_proteomics  \
# Sample_ID
# S001                   0.222           0.2560           0.6650
# S002                   0.984           0.1350           0.3340
# S003                     NaN          -0.2400           1.0400
# S005                   0.243          -0.0993           0.7570
# S006                   0.311           0.3750           0.0131
#
#            AADAT_proteomics  AAED1_proteomics  AAGAB_proteomics  \
# Sample_ID
# S001                 1.2800           -0.3390             0.412
# S002                 1.3000            0.1390             1.330
# S003                -0.0213           -0.0479             0.419
# S005                 0.7400           -0.9290             0.229
# S006                -1.1000               NaN             0.565
#
#            AAK1_proteomics  ...  ZZZ3-S397_phosphoproteomics  \
# Sample_ID                   ...
# S001                -0.664  ...                      0.18400
# S002                -0.367  ...                     -0.17100
# S003                -0.500  ...                          NaN
# S005                -0.223  ...                      0.13970
# S006                -0.101  ...                     -0.15875
#
#            ZZZ3-S411_phosphoproteomics  ZZZ3-S420_phosphoproteomics  \
# Sample_ID
# S001                               NaN                          NaN
# S002                               NaN                          NaN
# S003                               NaN                          NaN
# S005                               NaN                          NaN
# S006                               NaN                          NaN
#
#            ZZZ3-S424_phosphoproteomics  ZZZ3-S426_phosphoproteomics  \
# Sample_ID
# S001                               NaN                     -0.20500
# S002                            -0.393                     -0.17100
# S003                               NaN                          NaN
# S005                               NaN                     -0.55900
# S006                             0.196                      0.06175
#
#            ZZZ3-S468_phosphoproteomics  ZZZ3-S89_phosphoproteomics  \
# Sample_ID
# S001                               NaN                         NaN
# S002                               NaN                        0.29
# S003                               NaN                         NaN
# S005                               NaN                         NaN
# S006                               NaN                         NaN
#
#            ZZZ3-T415_phosphoproteomics  ZZZ3-T418_phosphoproteomics  \
# Sample_ID
# S001                               NaN                          NaN
# S002                               NaN                       0.1605
# S003                               NaN                          NaN
# S005                               NaN                          NaN
# S006                               NaN                          NaN
#
#            ZZZ3-Y399_phosphoproteomics
# Sample_ID
# S001                               NaN
# S002                           -0.0635
# S003                               NaN
# S005                            0.2980
# S006                           -0.2900
#
# [5 rows x 84211 columns]

# %% [markdown]
# Joining only specific columns.
# (Note that when a gene is selected from the phosphoproteomics dataframe, data for all sites of the gene are selected. The same is done for acetylproteomics data.)

# %%
prot_and_phos_selected = en.join_omics_to_omics(
    df1_name="proteomics", 
    df2_name="phosphoproteomics", 
    genes1="A1BG", 
    genes2="PIK3CA")

prot_and_phos_selected.head()
# Out:
#            A1BG_proteomics  PIK3CA-S312_phosphoproteomics  \
# Sample_ID
# S001                -1.180                       -0.00615
# S002                -0.685                       -0.02220
# S003                -0.528                            NaN
# S005                -1.670                            NaN
# S006                -0.374                        0.43600
#
#            PIK3CA-T313_phosphoproteomics
# Sample_ID
# S001                              0.0731
# S002                                 NaN
# S003                              0.0830
# S005                             -0.8460
# S006                                 NaN

# %% [markdown]
# ## <code>join_metadata_to_omics</code>
#
# The <code>join_metadata_to_omics</code> function joins a metadata dataframe (e.g. clinical or derived_molecular) with an -omics dataframe:

# %%
clin_and_tran = en.join_metadata_to_omics(metadata_df_name="clinical", omics_df_name="transcriptomics")
clin_and_tran.head()
# Out:
#           Patient_ID Proteomics_Tumor_Normal        Country  \
# Sample_ID
# S001       C3L-00006                   Tumor  United States
# S002       C3L-00008                   Tumor  United States
# S003       C3L-00032                   Tumor  United States
# S005       C3L-00090                   Tumor  United States
# S006       C3L-00098                   Tumor  United States
#
#           Histologic_Grade_FIGO Myometrial_invasion_Specify Histologic_type  \
# Sample_ID
# S001               FIGO grade 1                  under 50 %    Endometrioid
# S002               FIGO grade 1                  under 50 %    Endometrioid
# S003               FIGO grade 2                  under 50 %    Endometrioid
# S005               FIGO grade 2                  under 50 %    Endometrioid
# S006                        NaN                  under 50 %          Serous
#
#           Treatment_naive Tumor_purity Path_Stage_Primary_Tumor-pT  \
# Sample_ID
# S001                  YES       Normal              pT1a (FIGO IA)
# S002                  YES       Normal              pT1a (FIGO IA)
# S003                  YES       Normal              pT1a (FIGO IA)
# S005                  YES       Normal              pT1a (FIGO IA)
# S006                  YES       Normal              pT1a (FIGO IA)
#
#           Path_Stage_Reg_Lymph_Nodes-pN  ... ZWILCH_transcriptomics  \
# Sample_ID                                ...
# S001                                pN0  ...                  11.06
# S002                                pNX  ...                  10.87
# S003                                pN0  ...                  10.06
# S005                                pNX  ...                  10.29
# S006                                pNX  ...                  10.36
#
#           ZWINT_transcriptomics ZXDA_transcriptomics ZXDB_transcriptomics  \
# Sample_ID
# S001                      10.73                 8.40                 9.78
# S002                      11.43                 8.39                 9.14
# S003                      10.13                 8.35                 9.27
# S005                      10.41                 9.10                 9.59
# S006                      11.24                 8.60                 9.44
#
#            ZXDC_transcriptomics  ZYG11A_transcriptomics  \
# Sample_ID
# S001                      10.88                    5.93
# S002                      10.38                    7.25
# S003                      10.46                    6.85
# S005                      10.15                    7.89
# S006                      11.80                    9.32
#
#            ZYG11B_transcriptomics ZYX_transcriptomics ZZEF1_transcriptomics  \
# Sample_ID
# S001                        11.52               10.23                 11.50
# S002                        11.64               10.64                 11.26
# S003                        11.60               10.21                 11.51
# S005                        11.90               10.21                 11.34
# S006                        11.97                9.77                 11.37
#
#           ZZZ3_transcriptomics
# Sample_ID
# S001                     11.47
# S002                     11.57
# S003                     11.09
# S005                     11.51
# S006                     12.35
#
# [5 rows x 28083 columns]

# %% [markdown]
# Joining only specific columns:

# %%
clin_and_tran = en.join_metadata_to_omics(
    metadata_df_name="clinical", 
    omics_df_name="transcriptomics", 
    metadata_cols = ["Age", "Histologic_type"], 
    omics_genes="ZZZ3")

clin_and_tran.head()
# Out:
#             Age Histologic_type  ZZZ3_transcriptomics
# Sample_ID
# S001       64.0    Endometrioid                 11.47
# S002       58.0    Endometrioid                 11.57
# S003       50.0    Endometrioid                 11.09
# S005       75.0    Endometrioid                 11.51
# S006       63.0          Serous                 12.35

# %% [markdown]
# ## <code>join_metadata_to_metadata</code>
#
# The <code>join_metadata_to_metadata</code> function joins two metadata dataframes (e.g. clinical or derived_molecular) to each other. Note how we passed a column name to select from the clinical dataframe, but passing <code>None</code> for the column parameter for the derived_molecular dataframe caused the entire dataframe to be selected. We could have omitted the <code>cols2</code> parameter altogether, as it is assigned to None by default.

# %%
hist_and_derived_molecular = en.join_metadata_to_metadata(
    df1_name="clinical",
    df2_name="derived_molecular",
    cols1="Histologic_type",
    cols2=None) # Could have omitted cols2=None, as that's the default value

hist_and_derived_molecular.head()
# Out:
#           Histologic_type     Estrogen_Receptor  Estrogen_Receptor_%  \
# Sample_ID
# S001         Endometrioid  Cannot be determined                  NaN
# S002         Endometrioid  Cannot be determined                  NaN
# S003         Endometrioid  Cannot be determined                  NaN
# S005         Endometrioid  Cannot be determined                  NaN
# S006               Serous  Cannot be determined                  NaN
#
#           Progesterone_Receptor  Progesterone_Receptor_%  \
# Sample_ID
# S001       Cannot be determined                      NaN
# S002       Cannot be determined                      NaN
# S003       Cannot be determined                      NaN
# S005       Cannot be determined                      NaN
# S006       Cannot be determined                      NaN
#
#                                 MLH1                       MLH2  \
# Sample_ID
# S001       Intact nuclear expression  Intact nuclear expression
# S002       Intact nuclear expression  Intact nuclear expression
# S003       Intact nuclear expression  Intact nuclear expression
# S005       Intact nuclear expression  Intact nuclear expression
# S006       Intact nuclear expression  Intact nuclear expression
#
#                                  MSH6                        PMS2  \
# Sample_ID
# S001       Loss of nuclear expression   Intact nuclear expression
# S002        Intact nuclear expression  Loss of nuclear expression
# S003        Intact nuclear expression   Intact nuclear expression
# S005        Intact nuclear expression   Intact nuclear expression
# S006        Intact nuclear expression   Intact nuclear expression
#
#                             p53  ... Log2_variant_total Log2_SNP_total  \
# Sample_ID                        ...
# S001       Cannot be determined  ...          10.062046       9.984418
# S002       Cannot be determined  ...           8.861087       8.330917
# S003       Cannot be determined  ...           5.321928       5.000000
# S005       Cannot be determined  ...           5.672425       5.523562
# S006                     Normal  ...           6.108524       5.954196
#
#            Log2_INDEL_total  Genomics_subtype  Mutation_signature_C>A  \
# Sample_ID
# S001               5.832890             MSI-H                8.300395
# S002               7.169925             MSI-H               14.641745
# S003               3.169925           CNV_low               16.129032
# S005               2.584963           CNV_low               17.777778
# S006               3.000000          CNV_high                9.836066
#
#            Mutation_signature_C>G  Mutation_signature_C>T  \
# Sample_ID
# S001                     1.482213               72.529644
# S002                     2.803738               64.485981
# S003                     3.225806               70.967742
# S005                     8.888889               62.222222
# S006                    13.114754               62.295082
#
#            Mutation_signature_T>C  Mutation_signature_T>A  \
# Sample_ID
# S001                    14.426877                1.383399
# S002                    15.264798                0.934579
# S003                     3.225806                3.225806
# S005                     8.888889                2.222222
# S006                     3.278689                8.196721
#
#            Mutation_signature_T>G
# Sample_ID
# S001                     1.877470
# S002                     1.869159
# S003                     3.225806
# S005                     0.000000
# S006                     3.278689
#
# [5 rows x 126 columns]

# %% [markdown]
# ## <code>join_omics_to_mutations</code>
#
# The <code>join_omics_to_mutations</code> function joins an -omics dataframe with the mutation data for a specified gene or genes. Because there may be multiple mutations for one gene in a single sample, the mutation type and location data are returned in lists by default. If there is no mutation for the gene in a particular sample, the list contains either "Wildtype_Tumor" or "Wildtype_Normal", depending on whether it's a tumor or normal sample. The mutation status column contains either "Single_mutation", "Multiple_mutation", "Wildtype_Tumor", or "Wildtype_Normal", for help with parsing.
#
# The function has the ability to filter multiple mutations down to just one mutation. It first prioritizes mutations and locations (hotspots) that you pass to the optional <code>mutations_filter</code> parameter. Mutations and locations earlier in your filtering list are given priority over mutations and locations later in the list. When a sample has multiple mutations in a gene, but none of them were in your filter, the function chooses truncations over missense mutations, and silent mutations last of all. Between mutations of the same type, the function chooses mutations occurring earlier in the sequence. To filter all mutations based on this default hierarchy, simply pass an empty list to the <code>mutations_filter</code> parameter. Passing nothing to the <code>mutations_filter</code> parameter will cause no filtering to be done.
#
# Note that when multiple mutations are filtered, the Mutation_Status column is still included, so that if there were originally multiple mutations, you can easily know it.
#
# If you wish to drop the location columns, pass <code>False</code> to the optional show_location parameter.
#
# First, we demonstrate the function with no filtering of multiple mutations. Note that the Mutation and Location column values are in lists, even if there is only one mutation.

# %%
selected_acet_and_PTEN_mut = en.join_omics_to_mutations(
    omics_df_name="acetylproteomics",
    mutations_genes="PTEN", 
    omics_genes=["AAGAB", "AACS"])

selected_acet_and_PTEN_mut.head(10)
# Out:
#            AAGAB-K290_acetylproteomics  AACS-K391_acetylproteomics  \
# Sample_ID
# S001                             0.461                         NaN
# S002                             1.770                         NaN
# S003                            -0.815                         NaN
# S005                               NaN                         NaN
# S006                             0.205                         NaN
# S007                             0.403                         NaN
# S008                             0.792                         NaN
# S009                               NaN                         NaN
# S010                            -1.110                         NaN
# S011                             0.400                         NaN
#
#                                     PTEN_Mutation           PTEN_Location  \
# Sample_ID
# S001       [Missense_Mutation, Nonsense_Mutation]      [p.R130Q, p.R233*]
# S002                          [Missense_Mutation]               [p.G127R]
# S003                          [Nonsense_Mutation]               [p.W111*]
# S005                          [Missense_Mutation]               [p.R130G]
# S006                             [Wildtype_Tumor]           [No_mutation]
# S007       [Missense_Mutation, Missense_Mutation]       [p.Y68C, p.R130G]
# S008         [Frame_Shift_Ins, Nonsense_Mutation]  [p.H118Qfs*8, p.Y180*]
# S009                             [Wildtype_Tumor]           [No_mutation]
# S010                          [Missense_Mutation]               [p.R130G]
# S011         [Missense_Mutation, Frame_Shift_Ins]       [p.H93R, p.E242*]
#
#           PTEN_Mutation_Status Sample_Status
# Sample_ID
# S001         Multiple_mutation         Tumor
# S002           Single_mutation         Tumor
# S003           Single_mutation         Tumor
# S005           Single_mutation         Tumor
# S006            Wildtype_Tumor         Tumor
# S007         Multiple_mutation         Tumor
# S008         Multiple_mutation         Tumor
# S009            Wildtype_Tumor         Tumor
# S010           Single_mutation         Tumor
# S011         Multiple_mutation         Tumor

# %% [markdown]
# Using the mutations filtering functionality. Notice how mutations matching the mutation types and locations in the filter are prioritized, even if they occur later in the sequence than others, and how filter values earlier in the list are prioritized over values later in the list.

# %%
selected_acet_and_PTEN_mut = en.join_omics_to_mutations(
    omics_df_name="acetylproteomics",
    mutations_genes="PTEN", 
    omics_genes=["AAGAB", "AACS"],
    mutations_filter=["Nonsense_Mutation", "p.R130G", "p.Y68C", "p.H93R"])

selected_acet_and_PTEN_mut.head(10)
# Out:
#            AAGAB-K290_acetylproteomics  AACS-K391_acetylproteomics  \
# Sample_ID
# S001                             0.461                         NaN
# S002                             1.770                         NaN
# S003                            -0.815                         NaN
# S005                               NaN                         NaN
# S006                             0.205                         NaN
# S007                             0.403                         NaN
# S008                             0.792                         NaN
# S009                               NaN                         NaN
# S010                            -1.110                         NaN
# S011                             0.400                         NaN
#
#                PTEN_Mutation PTEN_Location PTEN_Mutation_Status Sample_Status
# Sample_ID
# S001       Nonsense_Mutation       p.R233*    Multiple_mutation         Tumor
# S002       Missense_Mutation       p.G127R      Single_mutation         Tumor
# S003       Nonsense_Mutation       p.W111*      Single_mutation         Tumor
# S005       Missense_Mutation       p.R130G      Single_mutation         Tumor
# S006          Wildtype_Tumor   No_mutation       Wildtype_Tumor         Tumor
# S007       Missense_Mutation       p.R130G    Multiple_mutation         Tumor
# S008       Nonsense_Mutation       p.Y180*    Multiple_mutation         Tumor
# S009          Wildtype_Tumor   No_mutation       Wildtype_Tumor         Tumor
# S010       Missense_Mutation       p.R130G      Single_mutation         Tumor
# S011       Missense_Mutation        p.H93R    Multiple_mutation         Tumor

# %% [markdown]
# Using the default filtering hierarchy. Notice how without any values in the filter list, all truncations are chosen over missense mutations, and mutations earlier in the sequence are chosen over mutations later in it.

# %%
selected_acet_and_PTEN_mut = en.join_omics_to_mutations(
    omics_df_name="acetylproteomics",
    mutations_genes="PTEN", 
    omics_genes=["AAGAB", "AACS"],
    mutations_filter=[])

selected_acet_and_PTEN_mut.head(10)
# Out:
#            AAGAB-K290_acetylproteomics  AACS-K391_acetylproteomics  \
# Sample_ID
# S001                             0.461                         NaN
# S002                             1.770                         NaN
# S003                            -0.815                         NaN
# S005                               NaN                         NaN
# S006                             0.205                         NaN
# S007                             0.403                         NaN
# S008                             0.792                         NaN
# S009                               NaN                         NaN
# S010                            -1.110                         NaN
# S011                             0.400                         NaN
#
#                PTEN_Mutation PTEN_Location PTEN_Mutation_Status Sample_Status
# Sample_ID
# S001       Nonsense_Mutation       p.R233*    Multiple_mutation         Tumor
# S002       Missense_Mutation       p.G127R      Single_mutation         Tumor
# S003       Nonsense_Mutation       p.W111*      Single_mutation         Tumor
# S005       Missense_Mutation       p.R130G      Single_mutation         Tumor
# S006          Wildtype_Tumor   No_mutation       Wildtype_Tumor         Tumor
# S007       Missense_Mutation        p.Y68C    Multiple_mutation         Tumor
# S008       Nonsense_Mutation       p.Y180*    Multiple_mutation         Tumor
# S009          Wildtype_Tumor   No_mutation       Wildtype_Tumor         Tumor
# S010       Missense_Mutation       p.R130G      Single_mutation         Tumor
# S011         Frame_Shift_Ins       p.E242*    Multiple_mutation         Tumor

# %% [markdown]
# ## <code>join_metadata_to_mutations</code>
#
# The <code>join_metadata_to_mutations</code> function works exactly like <code>join_omics_to_mutations</code>, except that it works with metadata dataframes (e.g. clinical and derived molecular) instead of omics dataframes. It also can filter multiple mutations, which you control through the <code>mutations_filter</code> parameter, and has the ability to hide the location colunms.

# %%
hist_and_PTEN = en.join_metadata_to_mutations(
    metadata_df_name="clinical",
    mutations_genes="PTEN",
    metadata_cols="Histologic_type")

hist_and_PTEN.head()
# Out:
#           Histologic_type                           PTEN_Mutation  \
# Sample_ID
# S001         Endometrioid  [Missense_Mutation, Nonsense_Mutation]
# S002         Endometrioid                     [Missense_Mutation]
# S003         Endometrioid                     [Nonsense_Mutation]
# S005         Endometrioid                     [Missense_Mutation]
# S006               Serous                        [Wildtype_Tumor]
#
#                 PTEN_Location PTEN_Mutation_Status Sample_Status
# Sample_ID
# S001       [p.R130Q, p.R233*]    Multiple_mutation         Tumor
# S002                [p.G127R]      Single_mutation         Tumor
# S003                [p.W111*]      Single_mutation         Tumor
# S005                [p.R130G]      Single_mutation         Tumor
# S006            [No_mutation]       Wildtype_Tumor         Tumor

# %% [markdown]
# With multiple mutations filtered:

# %%
hist_and_PTEN = en.join_metadata_to_mutations(
    metadata_df_name="clinical",
    mutations_genes="PTEN",
    metadata_cols="Histologic_type",
    mutations_filter=["Nonsense_Mutation"])

hist_and_PTEN.head()
# Out:
#           Histologic_type      PTEN_Mutation PTEN_Location  \
# Sample_ID
# S001         Endometrioid  Nonsense_Mutation       p.R233*
# S002         Endometrioid  Missense_Mutation       p.G127R
# S003         Endometrioid  Nonsense_Mutation       p.W111*
# S005         Endometrioid  Missense_Mutation       p.R130G
# S006               Serous     Wildtype_Tumor   No_mutation
#
#           PTEN_Mutation_Status Sample_Status
# Sample_ID
# S001         Multiple_mutation         Tumor
# S002           Single_mutation         Tumor
# S003           Single_mutation         Tumor
# S005           Single_mutation         Tumor
# S006            Wildtype_Tumor         Tumor

# %% [markdown]
# # Exporting dataframes
#
# If you wish to export a dataframe to a file, simply call the dataframe's to_csv method, passing the path you wish to save the file to, and the value separator you want:

# %%
more_selected_acet_and_mut.to_csv(path_or_buf="more_selected_acet_and_mut.tsv", sep='\t')
