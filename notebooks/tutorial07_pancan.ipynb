# %% [markdown]
# # Tutorial 7: Pancan data access
#
# This tutorial shows how to use the `cptac.pancan` submodule to access data from the harmonized pipelines for all cancer types.
#
# Before the harmonized pipelines, the team working on each cancer type had their own pipeline for each data type. So for example, the ccRCC team ran the ccRCC data through their own transcriptomics pipeline, and the HNSCC team ran the HNSCC data through a different transcriptomics pipeline. However, this made it hard to study trends across multiple cancer types, since each cancer type's data had been processed differently.
#
# To fix this problem, all data for all cancer types was run through the same pipelines for each data type. These are the harmonized pipelines. Now, for example, you can get transcriptomics data for both ccRCC and HNSCC (and all other cancer types) that came from the same pipeline.
#
# For some data types, multiple harmonized pipelines were available. In this cases, all cancers were run through each pipeline, and you can choose which one to use. For example, you can get transcriptomics data from either the BCM pipeline, the Broad pipeline, or the WashU pipeline. But whichever pipeline you choose, you can get transcriptomics data for all cancer types through that one pipeline.
#
# First, we'll import the package.

# %%
import cptac

# %% [markdown]
# We can list which cancers we have data for.

# %%
cptac.get_cancer_options()
# Out:
# ['brca', 'ccrcc', 'coad', 'gbm', 'hnscc', 'lscc', 'luad', 'ov', 'pdac', 'ucec']

# %% [markdown]
# ## Load the BRCA dataset

# %%
br = cptac.Brca()

# %% [markdown]
# We can list which data types are available from which sources.

# %%
br.list_data_sources()
# Out:
#                   Data type       Available sources
# 0                       CNV              awg, washu
# 1          acetylproteomics                awg, pdc
# 2                  clinical          awg, mssm, pdc
# 3   deconvolution_cibersort                   washu
# 4       deconvolution_xcell                   washu
# 5         derived_molecular                     awg
# 6         phosphoproteomics         awg, pdc, umich
# 7                proteomics         awg, pdc, umich
# 8          somatic_mutation  awg, harmonized, washu
# 9           transcriptomics  awg, bcm, broad, washu
# 10             tumor_purity                   washu

# %% [markdown]
# ## Download
#
# Each file will be automatically downloaded when requested, but authentication through your Box account is required to download pancan data.
#
# See the end of this tutorial for how to download files on a remote computer that doesn't have a web browser for logging into Box.

# %% [markdown]
# Let's get some data tables.

# %%
br.get_clinical(source="mssm")
# Out:
# Name       tumor_code discovery_study  \
# Patient_ID
# 01BR001            BR             NaN
# 01BR015            BR             NaN
# 01BR017            BR             NaN
# 01BR018            BR             NaN
# 01BR025            BR             NaN
# ...               ...             ...
# 21BR003            BR             NaN
# 21BR010            BR             NaN
# 22BR003            BR             NaN
# 22BR005            BR             NaN
# 22BR006            BR             NaN
#
# Name       discovery_study/type_of_analyzed_samples consent/age consent/sex  \
# Patient_ID
# 01BR001                                         NaN          55      Female
# 01BR015                                         NaN          35      Female
# 01BR017                                         NaN          45      Female
# 01BR018                                         NaN          66      Female
# 01BR025                                         NaN          62      Female
# ...                                             ...         ...         ...
# 21BR003                                         NaN          46      Female
# 21BR010                                         NaN          71      Female
# 22BR003                                         NaN          30      Female
# 22BR005                                         NaN          46      Female
# 22BR006                                         NaN          55      Female
#
# Name                     consent/race       consent/ethnicity  \
# Patient_ID
# 01BR001     Black or African American  Not Hispanic or Latino
# 01BR015                         White  Not Hispanic or Latino
# 01BR017                         White  Not Hispanic or Latino
# 01BR018                         White  Not Hispanic or Latino
# 01BR025     Black or African American  Not Hispanic or Latino
# ...                               ...                     ...
# 21BR003                         White      Hispanic or Latino
# 21BR010                         White      Hispanic or Latino
# 22BR003                         White  Not Hispanic or Latino
# 22BR005                         White  Not Hispanic or Latino
# 22BR006     Black or African American  Not Hispanic or Latino
#
# Name       consent/ethnicity_race_ancestry_identified  \
# Patient_ID
# 01BR001                                           NaN
# 01BR015                                           NaN
# 01BR017                                           NaN
# 01BR018                                           NaN
# 01BR025                                           NaN
# ...                                               ...
# 21BR003                                           NaN
# 21BR010                                           NaN
# 22BR003                                           NaN
# 22BR005                                           NaN
# 22BR006                                           NaN
#
# Name       consent/collection_in_us consent/participant_country  ...  \
# Patient_ID                                                       ...
# 01BR001                         NaN                         NaN  ...
# 01BR015                         NaN                         NaN  ...
# 01BR017                         NaN                         NaN  ...
# 01BR018                         NaN                         NaN  ...
# 01BR025                         NaN                         NaN  ...
# ...                             ...                         ...  ...
# 21BR003                         NaN                         NaN  ...
# 21BR010                         NaN                         NaN  ...
# 22BR003                         NaN                         NaN  ...
# 22BR005                         NaN                         NaN  ...
# 22BR006                         NaN                         NaN  ...
#
# Name       follow-up/additional_treatment_for_new_tumor_radiation  \
# Patient_ID
# 01BR001                                                   NaN
# 01BR015                                                   NaN
# 01BR017                                                   NaN
# 01BR018                                                   NaN
# 01BR025                                                   NaN
# ...                                                       ...
# 21BR003                                                   NaN
# 21BR010                                                   NaN
# 22BR003                                                   NaN
# 22BR005                                                   NaN
# 22BR006                                                   NaN
#
# Name       follow-up/additional_treatment_for_new_tumor_pharmaceutical  \
# Patient_ID
# 01BR001                                                   NaN
# 01BR015                                                   NaN
# 01BR017                                                   NaN
# 01BR018                                                   NaN
# 01BR025                                                   NaN
# ...                                                       ...
# 21BR003                                                   NaN
# 21BR010                                                   NaN
# 22BR003                                                   NaN
# 22BR005                                                   NaN
# 22BR006                                                   NaN
#
# Name       follow-up/additional_treatment_for_new_tumor_immunological  \
# Patient_ID
# 01BR001                                                   NaN
# 01BR015                                                   NaN
# 01BR017                                                   NaN
# 01BR018                                                   NaN
# 01BR025                                                   NaN
# ...                                                       ...
# 21BR003                                                   NaN
# 21BR010                                                   NaN
# 22BR003                                                   NaN
# 22BR005                                                   NaN
# 22BR006                                                   NaN
#
# Name       follow-up/days_from_date_of_initial_pathologic_diagnosis_to_date_of_additional_surgery_for_new_tumor  \
# Patient_ID
# 01BR001                                                   NaN
# 01BR015                                                   NaN
# 01BR017                                                   NaN
# 01BR018                                                   NaN
# 01BR025                                                   NaN
# ...                                                       ...
# 21BR003                                                   NaN
# 21BR010                                                   NaN
# 22BR003                                                   NaN
# 22BR005                                                   NaN
# 22BR006                                                   NaN
#
# Name       follow-up/cause_of_death  \
# Patient_ID
# 01BR001                         NaN
# 01BR015                         NaN
# 01BR017                         NaN
# 01BR018                         NaN
# 01BR025                         NaN
# ...                             ...
# 21BR003                         NaN
# 21BR010                         NaN
# 22BR003                         NaN
# 22BR005                         NaN
# 22BR006                         NaN
#
# Name       follow-up/days_from_date_of_initial_pathologic_diagnosis_to_date_of_death  \
# Patient_ID
# 01BR001                                                   NaN
# 01BR015                                                   NaN
# 01BR017                                                   NaN
# 01BR018                                                   NaN
# 01BR025                                                   NaN
# ...                                                       ...
# 21BR003                                                   NaN
# 21BR010                                                   NaN
# 22BR003                                                   NaN
# 22BR005                                                   NaN
# 22BR006                                                 282.0
#
# Name       Recurrence-free survival Overall survial  \
# Patient_ID
# 01BR001                         NaN           421.0
# 01BR015                         NaN           347.0
# 01BR017                         NaN           413.0
# 01BR018                         NaN           384.0
# 01BR025                         NaN           601.0
# ...                             ...             ...
# 21BR003                         NaN             NaN
# 21BR010                         NaN           327.0
# 22BR003                         NaN             NaN
# 22BR005                         NaN           348.0
# 22BR006                         NaN           282.0
#
# Name       Recurrence status (1, yes; 0, no)  \
# Patient_ID
# 01BR001                                    0
# 01BR015                                    0
# 01BR017                                    0
# 01BR018                                    0
# 01BR025                                    0
# ...                                      ...
# 21BR003                                    0
# 21BR010                                    0
# 22BR003                                    0
# 22BR005                                    0
# 22BR006                                    0
#
# Name       Survial status (1, dead; 0, alive)
# Patient_ID
# 01BR001                                   0.0
# 01BR015                                   0.0
# 01BR017                                   0.0
# 01BR018                                   0.0
# 01BR025                                   0.0
# ...                                       ...
# 21BR003                                   NaN
# 21BR010                                   0.0
# 22BR003                                   NaN
# 22BR005                                   0.0
# 22BR006                                   1.0
#
# [126 rows x 113 columns]

# %%
br.get_somatic_mutation(source="washu")
# Out:
# Name            Gene           Mutation       Location  Entrez_Gene_Id Center  \
# Patient_ID
# 01BR001       PIK3CD  Missense_Mutation        p.R785W               0      .
# 01BR001         GLI4  Missense_Mutation        p.R231G               0      .
# 01BR001         PLEC  Missense_Mutation       p.L3732R               0      .
# 01BR001        MFSD3  Missense_Mutation        p.G292A               0      .
# 01BR001       PPFIA1             Silent        p.L794L               0      .
# ...              ...                ...            ...             ...    ...
# CPT001846   ANKRD33B  Missense_Mutation        p.V342G               0      .
# CPT001846      NPY1R  Missense_Mutation         p.F18S               0      .
# CPT001846      PLRG1  Missense_Mutation        p.L477F               0      .
# CPT001846      STAG2        Splice_Site  p.X607_splice               0      .
# CPT001846      CDH26  Nonsense_Mutation        p.R228*               0      .
#
# Name       NCBI_Build Chromosome  Start_Position  End_Position Strand  ...  \
# Patient_ID                                                             ...
# 01BR001        GRCh38       chr1         9722533       9722533      +  ...
# 01BR001        GRCh38       chr8       143276364     143276364      +  ...
# 01BR001        GRCh38       chr8       143919037     143919037      +  ...
# 01BR001        GRCh38       chr8       144510642     144510642      +  ...
# 01BR001        GRCh38      chr11        70355705      70355705      +  ...
# ...               ...        ...             ...           ...    ...  ...
# CPT001846      GRCh38       chr5        10649653      10649653      +  ...
# CPT001846      GRCh38       chr4       163326502     163326502      +  ...
# CPT001846      GRCh38       chr4       154537340     154537340      +  ...
# CPT001846      GRCh38       chrX       124063207     124063207      +  ...
# CPT001846      GRCh38      chr20        59984779      59984779      +  ...
#
# Name       ExAC_AC_AN_Adj ExAC_AC_AN ExAC_AC_AN_AFR ExAC_AC_AN_AMR  \
# Patient_ID
# 01BR001               NaN        NaN            NaN            NaN
# 01BR001               NaN        NaN            NaN            NaN
# 01BR001               NaN        NaN            NaN            NaN
# 01BR001               NaN        NaN            NaN            NaN
# 01BR001               NaN        NaN            NaN            NaN
# ...                   ...        ...            ...            ...
# CPT001846             NaN        NaN            NaN            NaN
# CPT001846             NaN        NaN            NaN            NaN
# CPT001846             NaN        NaN            NaN            NaN
# CPT001846             NaN        NaN            NaN            NaN
# CPT001846             NaN        NaN            NaN            NaN
#
# Name       ExAC_AC_AN_EAS  ExAC_AC_AN_FIN ExAC_AC_AN_NFE ExAC_AC_AN_OTH  \
# Patient_ID
# 01BR001               NaN             NaN            NaN            NaN
# 01BR001               NaN             NaN            NaN            NaN
# 01BR001               NaN             NaN            NaN            NaN
# 01BR001               NaN             NaN            NaN            NaN
# 01BR001               NaN             NaN            NaN            NaN
# ...                   ...             ...            ...            ...
# CPT001846             NaN             NaN            NaN            NaN
# CPT001846             NaN             NaN            NaN            NaN
# CPT001846             NaN             NaN            NaN            NaN
# CPT001846             NaN             NaN            NaN            NaN
# CPT001846             NaN             NaN            NaN            NaN
#
# Name       ExAC_AC_AN_SAS ExAC_FILTER
# Patient_ID
# 01BR001               NaN         NaN
# 01BR001               NaN         NaN
# 01BR001               NaN         NaN
# 01BR001               NaN         NaN
# 01BR001               NaN         NaN
# ...                   ...         ...
# CPT001846             NaN         NaN
# CPT001846             NaN         NaN
# CPT001846             NaN         NaN
# CPT001846             NaN         NaN
# CPT001846             NaN         NaN
#
# [33689 rows x 124 columns]

# %%
br.get_proteomics(source="umich")
# Out:
# Name                     ARF5              M6PR             ESRRA  \
# Database_ID ENSP00000000233.5 ENSP00000000412.3 ENSP00000000442.6
# Patient_ID
# 01BR001              0.012367         -0.945999               NaN
# 01BR008             -0.514386          0.462307          0.230124
# 01BR009             -0.210782         -0.085055          0.380296
# 01BR010              0.105457          0.351335         -0.322798
# 01BR015             -0.509298         -0.874164               NaN
# ...                       ...               ...               ...
# 21BR010              0.528298         -0.127929         -0.497360
# 22BR005             -0.549542          0.134236               NaN
# 22BR006              0.336092          0.125742               NaN
# CPT000814           -0.518995          0.262582          0.277980
# CPT001846            0.652513         -0.165268          0.809801
#
# Name                    FKBP4           NDUFAF7             FUCA2  \
# Database_ID ENSP00000001008.4 ENSP00000002125.4 ENSP00000002165.5
# Patient_ID
# 01BR001             -0.478170          1.135840         -0.512706
# 01BR008             -0.555968          0.491366         -0.656034
# 01BR009             -0.389491          1.255391         -0.608007
# 01BR010             -0.821610          0.241406         -0.500140
# 01BR015             -0.113804         -0.131347         -0.412813
# ...                       ...               ...               ...
# 21BR010             -0.151022          0.082288          0.447267
# 22BR005              0.580773         -0.080663         -0.056509
# 22BR006             -0.360510          0.086199          0.470607
# CPT000814            0.137505          0.600041         -1.041230
# CPT001846           -1.108263          0.557576          0.007854
#
# Name                   DBNDD1            SEMA3F              CFTR  \
# Database_ID ENSP00000002501.6 ENSP00000002829.3 ENSP00000003084.6
# Patient_ID
# 01BR001              0.750335         -0.274824               NaN
# 01BR008             -1.220890         -0.369282         -1.036441
# 01BR009             -0.231318          0.092870         -1.505195
# 01BR010             -0.137824          0.113791               NaN
# 01BR015              0.262210          0.042333               NaN
# ...                       ...               ...               ...
# 21BR010              0.151024          0.220194          0.516739
# 22BR005             -0.148632          0.260986               NaN
# 22BR006             -0.515990         -0.162247          1.003075
# CPT000814            0.513974         -0.012011               NaN
# CPT001846            0.213734         -0.721577         -2.695651
#
# Name                  CYP51A1  ...             DDHD1               WIZ  \
# Database_ID ENSP00000003100.8  ... ENSP00000500986.2 ENSP00000500993.1
# Patient_ID                     ...
# 01BR001             -0.278244  ...         -0.649127         -0.580869
# 01BR008             -0.059327  ...          0.632221               NaN
# 01BR009              0.206595  ...          0.450818               NaN
# 01BR010              0.498314  ...         -0.423470               NaN
# 01BR015             -0.657666  ...          0.406016         -0.493869
# ...                       ...  ...               ...               ...
# 21BR010             -0.230357  ...         -0.172151          0.636608
# 22BR005             -0.348578  ...          0.791937               NaN
# 22BR006              0.342987  ...         -0.080755               NaN
# CPT000814           -0.411714  ...         -2.011008               NaN
# CPT001846            0.296581  ...         -0.057923               NaN
#
# Name                     GBF1             APOA5               WIZ  \
# Database_ID ENSP00000501064.1 ENSP00000501141.1 ENSP00000501256.3
# Patient_ID
# 01BR001             -0.226667               NaN               NaN
# 01BR008              0.032873               NaN               NaN
# 01BR009             -0.341503               NaN               NaN
# 01BR010              0.360900               NaN               NaN
# 01BR015             -0.192847               NaN               NaN
# ...                       ...               ...               ...
# 21BR010              0.267400               NaN          -0.09507
# 22BR005              0.171712               NaN               NaN
# 22BR006              0.174904         -0.353412               NaN
# CPT000814            0.035445               NaN               NaN
# CPT001846            0.252335               NaN               NaN
#
# Name                     LDB1               WIZ              RFX7  \
# Database_ID ENSP00000501277.1 ENSP00000501300.1 ENSP00000501317.1
# Patient_ID
# 01BR001             -0.676185         -0.068202         -0.078207
# 01BR008             -0.015459          0.227424          0.325643
# 01BR009             -0.220239          0.125092          0.365397
# 01BR010             -0.451556         -0.098897          0.208643
# 01BR015              0.083639          0.966976         -0.012664
# ...                       ...               ...               ...
# 21BR010             -0.017522         -0.220463         -0.067717
# 22BR005              0.083980         -0.200083          0.155198
# 22BR006             -0.013793         -0.253829         -0.117960
# CPT000814           -1.385942          0.620827               NaN
# CPT001846            0.040722         -0.006118         -0.251360
#
# Name                   SWSAP1              SVIL
# Database_ID ENSP00000501355.1 ENSP00000501521.1
# Patient_ID
# 01BR001             -0.328420               NaN
# 01BR008             -0.606240               NaN
# 01BR009             -0.167392               NaN
# 01BR010             -0.729096          0.670307
# 01BR015              0.081968               NaN
# ...                       ...               ...
# 21BR010             -0.311446          0.602422
# 22BR005                   NaN          0.456801
# 22BR006                   NaN          1.094966
# CPT000814                 NaN               NaN
# CPT001846            0.443203               NaN
#
# [125 rows x 12922 columns]

# %% [markdown]
# ## Box authentication for remote downloads
#
# Normally, when you download the `cptac.pancan` data files you're required to log into your Box account, as these files are not released publicly. However, there may be situations where the computer you're running your analysis on doesn't have a web browser you can use to log in to Box. For example, you may be running your code in a remotely hosted notebook (e.g. Google Colabs), or on a computer cluster that you access using ssh.
#
# In these situations, follow these steps to take care of Box authenication:
# 1. On a computer where you do have access to a web browser to log in to Box, load the `cptac.pancan` module.
# 2. Call the `cptac.pancan.get_box_token` function. This will return a temporary access token that gives permission to download files from Box with your credentials. The token expires 1 hour after it's created.
# 3. On the remote computer, when you call the `cptac.pancan.download` function, copy and paste the access token you generated on your local machine into the `box_token` parameter of the function. The program will then be able to download the data files.
#
# Below is all the code you would need to call for this process on each machine. For security, we will not actually run it in this notebook.
#
# On your local machine:
# ```
# import cptac.pancan as pc
# pc.get_box_token()
# ```
#
# On the remote machine:
# ```
# import cptac.pancan as pc
# pc.download("pancanbrca", box_token=[INSERT TOKEN HERE])
# ```
