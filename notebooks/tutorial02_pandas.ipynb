# %% [markdown]
# # Tutorial 2: Accessing dataframes and using them with `pandas`
#
# A large portion of this package utilizes the functionality of pandas dataframes. Here we give a few specific instances of using dataframes with our package. For a more general overview of dataframes, see pandas [documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html) and [tutorials](https://www.datacamp.com/community/tutorials/pandas-tutorial-dataframe-python).

# %% [markdown]
# ## How do I install the package?
#
# Install the package from the [Python Package Index (PyPI)](https://pypi.org/project/cptac/) in the command line using the [pip package installer](https://pypi.org/project/pip/), with the name of the package:
#
# `pip install cptac`

# %% [markdown]
# ## How do I import the package once it has been installed?
#
# The cptac package has several cancer data sets. First import the entire package by entering the following:
#
# `import cptac`
#
# The data in the package is broken into specific cancer types. All available types can be seen with the command `cptac.list_cancer_options()`
#
# To get a data for a cancer, load the dataset object and assign it to a variable, like this:
#
# `en = cptac.Ucec()`

# %%
import cptac
en = cptac.Ucec()

# %% [markdown]
# ## Can I use multiple datasets at the same time?
#
# You can have multiple datasets loaded at the same time, just assign each one to its own variable.

# %%
ov = cptac.Ov()
co = cptac.Coad()

# %% [markdown]
# **NOTE: When using multiple data sets, be sure to check that each function used matches the expected data set, as each data set uses the same API.** For example, the command for retrieving clinical data is `get_clinical()` for all data sets, so make sure not to retrieve ovarian clinical data `ov.get_clinical()` when you meant to get the endometrial clinical data `en.get_clinical()`.

# %% [markdown]
# ## How do I access a particular dataframe?
#
# You can access a specific dataframe by calling the dataset's `get_dataframe` method and passing in a datatype and source. There are also helper "get" methods for each datatype, for example `get_clinical`, which works the same as `get_dataframe` but does not require the datatype parameter. (To see all available dataframes, call the dataset's `list_data_sources` function, e.g. `en.list_data_sources()`.)

# %%
en.list_data_sources()
# Out:
#                   Data type       Available sources
# 0                       CNV              awg, washu
# 1                  clinical          awg, mssm, pdc
# 2   deconvolution_cibersort                   washu
# 3       deconvolution_xcell                   washu
# 4                  followup                     awg
# 5         phosphoproteomics         awg, pdc, umich
# 6                proteomics         awg, pdc, umich
# 7          somatic_mutation  awg, harmonized, washu
# 8           transcriptomics  awg, bcm, broad, washu
# 9                 treatment                     awg
# 10             tumor_purity                   washu

# %%
proteomics = en.get_proteomics('umich')
proteomics.head()
# Out:
# Name         A1BG     A2M  A2ML1  A4GALT    AAAS    AACS   AADAT   AAED1  \
# Patient_ID
# C3L-00006  -1.180 -0.8630 -0.802   0.222  0.2560  0.6650  1.2800 -0.3390
# C3L-00008  -0.685 -1.0700 -0.684   0.984  0.1350  0.3340  1.3000  0.1390
# C3L-00032  -0.528 -1.3200  0.435     NaN -0.2400  1.0400 -0.0213 -0.0479
# C3L-00090  -1.670 -1.1900 -0.443   0.243 -0.0993  0.7570  0.7400 -0.9290
# C3L-00098  -0.374 -0.0206 -0.537   0.311  0.3750  0.0131 -1.1000     NaN
#
# Name        AAGAB   AAK1  ...   ZSWIM8  ZSWIM9    ZW10  ZWILCH  ZWINT   ZXDC  \
# Patient_ID                ...
# C3L-00006   0.412 -0.664  ... -0.08770     NaN  0.0229  0.1090    NaN -0.332
# C3L-00008   1.330 -0.367  ... -0.03560     NaN  0.3630  1.0700  0.737 -0.564
# C3L-00032   0.419 -0.500  ...  0.00112 -0.1450  0.0105 -0.1160    NaN  0.151
# C3L-00090   0.229 -0.223  ...  0.07250 -0.0552 -0.0714  0.0933  0.156 -0.398
# C3L-00098   0.565 -0.101  ... -0.17600     NaN -1.2200 -0.5620  0.937 -0.646
#
# Name         ZYG11B    ZYX   ZZEF1    ZZZ3
# Patient_ID
# C3L-00006  -0.43300 -1.020 -0.1230 -0.0859
# C3L-00008  -0.00461 -1.130 -0.0757 -0.4730
# C3L-00032  -0.07400 -0.540  0.3200 -0.4190
# C3L-00090  -0.07520 -0.797 -0.0301 -0.4670
# C3L-00098   0.20700 -1.850 -0.1760  0.0513
#
# [5 rows x 10999 columns]

# %% [markdown]
# ## How do I access specific columns in a dataframe?
#
# You'll probably want to get a feel for what data is in the dataframes you load. For example, say we want to know what kind of data is included in our proteomics dataframe. Each column in that dataframe contains the proteomics data for a different protein.
#
# You can view a list of column names (which is a list of protein names, in the case of the proteomics dataframe) by appending `.columns` to the end of a dataframe variable. (If you wish to see all of the column names, even if there are a lot, append `.columns.values` to the dataframe variable.)

# %%
proteomics.columns
# Out:
# Index(['A1BG', 'A2M', 'A2ML1', 'A4GALT', 'AAAS', 'AACS', 'AADAT', 'AAED1',
#        'AAGAB', 'AAK1',
#        ...
#        'ZSWIM8', 'ZSWIM9', 'ZW10', 'ZWILCH', 'ZWINT', 'ZXDC', 'ZYG11B', 'ZYX',
#        'ZZEF1', 'ZZZ3'],
#       dtype='object', name='Name', length=10999)

# %% [markdown]
# To access specific column (which is a specific protein's data, in the case of the proteomics dataframe), slice the column out of the dataframe using either of the following methods:
#
# `proteomics["A1BG"]`
#
# or
#
# `proteomics.A1BG`
#
# Both return the column as a [pandas series](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.html). The first method is useful when the name of the column you want is stored as a string variable.

# %%
protein = "A1BG"
A1BG_col = proteomics[protein]
A1BG_col.head()
# Out:
# Patient_ID
# C3L-00006   -1.180
# C3L-00008   -0.685
# C3L-00032   -0.528
# C3L-00090   -1.670
# C3L-00098   -0.374
# Name: A1BG, dtype: float64

# %% [markdown]
# This `dataframe["col_name"]` syntax also allows for selection of multiple columns by entering a list of column names.

# %%
proteins = ["A1BG","PTEN","TP53"]
selected_prot = proteomics[proteins]
selected_prot.head()
# Out:
# Name         A1BG   PTEN   TP53
# Patient_ID
# C3L-00006  -1.180 -0.526  0.295
# C3L-00008  -0.685 -0.830  0.277
# C3L-00032  -0.528 -0.941 -0.871
# C3L-00090  -1.670  0.730 -0.343
# C3L-00098  -0.374 -0.379  3.010

# %% [markdown]
# ## How do I access specific rows in a dataframe?
#
# You can access specific rows in a dataframe (which are specific samples, in the case of the CPTAC data) using the dataframe's `.iloc` (by row number) or `.loc` (by row name) method, which both return a pandas Series if you select one row, and a pandas DataFrame if you select multiple rows.

# %%
proteomics.iloc[0:5]
# Out:
# Name         A1BG     A2M  A2ML1  A4GALT    AAAS    AACS   AADAT   AAED1  \
# Patient_ID
# C3L-00006  -1.180 -0.8630 -0.802   0.222  0.2560  0.6650  1.2800 -0.3390
# C3L-00008  -0.685 -1.0700 -0.684   0.984  0.1350  0.3340  1.3000  0.1390
# C3L-00032  -0.528 -1.3200  0.435     NaN -0.2400  1.0400 -0.0213 -0.0479
# C3L-00090  -1.670 -1.1900 -0.443   0.243 -0.0993  0.7570  0.7400 -0.9290
# C3L-00098  -0.374 -0.0206 -0.537   0.311  0.3750  0.0131 -1.1000     NaN
#
# Name        AAGAB   AAK1  ...   ZSWIM8  ZSWIM9    ZW10  ZWILCH  ZWINT   ZXDC  \
# Patient_ID                ...
# C3L-00006   0.412 -0.664  ... -0.08770     NaN  0.0229  0.1090    NaN -0.332
# C3L-00008   1.330 -0.367  ... -0.03560     NaN  0.3630  1.0700  0.737 -0.564
# C3L-00032   0.419 -0.500  ...  0.00112 -0.1450  0.0105 -0.1160    NaN  0.151
# C3L-00090   0.229 -0.223  ...  0.07250 -0.0552 -0.0714  0.0933  0.156 -0.398
# C3L-00098   0.565 -0.101  ... -0.17600     NaN -1.2200 -0.5620  0.937 -0.646
#
# Name         ZYG11B    ZYX   ZZEF1    ZZZ3
# Patient_ID
# C3L-00006  -0.43300 -1.020 -0.1230 -0.0859
# C3L-00008  -0.00461 -1.130 -0.0757 -0.4730
# C3L-00032  -0.07400 -0.540  0.3200 -0.4190
# C3L-00090  -0.07520 -0.797 -0.0301 -0.4670
# C3L-00098   0.20700 -1.850 -0.1760  0.0513
#
# [5 rows x 10999 columns]

# %%
S001_row = proteomics.loc["C3L-00006"]
S001_row.head()
# Out:
# Name
# A1BG     -1.180
# A2M      -0.863
# A2ML1    -0.802
# A4GALT    0.222
# AAAS      0.256
# Name: C3L-00006, dtype: float64

# %% [markdown]
# ## How do I access specific rows and columns?
#
# In addition to selecting specific rows, you can also use `.loc` to select a subset of rows and columns, using lists.

# %%
samples = ["C3L-00006","C3L-00032","C3L-00413"]
proteins = ["A1BG","PTEN","TP53"]
proteomics.loc[samples, proteins]
# Out:
# Name         A1BG   PTEN    TP53
# Patient_ID
# C3L-00006  -1.180 -0.526  0.2950
# C3L-00032  -0.528 -0.941 -0.8710
# C3L-00413   0.150 -1.700  0.0213

# %% [markdown]
# ## How can I search using conditional statements?
#
# There are a variety of ways to use boolean statements to traverse a dataframe. A common way is to pass a boolean statement that selects the data you want to the `.loc` function. For example, if we want to see all the data for samples that have a positive protein expression level for the A1BG protein, we would pass the `.loc` function the boolean statement asking for rows containing values above zero for the A1BG column.

# %% [markdown]
# `.loc` has many functionalities. For a full list, see pandas documentation for [.loc](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html) and [indexing and slicing](https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html).

# %%
a1bg_positive = proteomics.loc[proteomics["A1BG"] > 0]
a1bg_positive.head()
# Out:
# Name          A1BG     A2M  A2ML1  A4GALT    AAAS    AACS  AADAT   AAED1  \
# Patient_ID
# C3L-00413   0.1500  0.9870  5.070   0.302 -0.1690  0.3980    NaN -0.2740
# C3L-00449   0.1810 -0.2830  0.689   0.104 -0.1300 -0.0683 -0.376 -0.0838
# C3L-00770   0.0499  0.0199 -0.125   0.477 -0.2520  0.8380 -0.100 -0.8510
# C3L-00771   0.7730  0.5460 -0.603     NaN  0.0555 -0.6390 -0.390  0.4670
# C3L-00780   0.5510  0.2030    NaN     NaN -0.4930  0.2110  1.060 -0.2800
#
# Name        AAGAB   AAK1  ...   ZSWIM8  ZSWIM9    ZW10  ZWILCH    ZWINT  \
# Patient_ID                ...
# C3L-00413   1.090  0.147  ...  0.34800  -0.484  0.1420   0.250 -0.14200
# C3L-00449   0.160  0.277  ...  0.22800     NaN  0.0206  -0.970      NaN
# C3L-00770   0.351 -0.582  ...  0.04910  -0.479  0.0548   0.933  0.00967
# C3L-00771  -0.366  0.427  ... -0.00835   0.119 -0.2960  -0.205 -0.07650
# C3L-00780   0.207  0.334  ...  0.30000     NaN  0.1420  -0.549      NaN
#
# Name         ZXDC  ZYG11B      ZYX    ZZEF1    ZZZ3
# Patient_ID
# C3L-00413   0.077 -0.1570 -0.87200 -0.00663 -0.0175
# C3L-00449  -0.452  0.1720  0.62600  0.34200 -0.2030
# C3L-00770  -1.140 -0.5410 -0.83800  0.02380 -0.0602
# C3L-00771   0.228  0.2370  1.05000  0.01850  0.5870
# C3L-00780  -0.390 -0.0972  0.00108  0.20000 -0.1940
#
# [5 rows x 10999 columns]

# %% [markdown]
# For another example, suppose we wanted to separate clinical information for samples that are serous vs. endometrioid, as recorded in the "Histologic_type" column.

# %%
clinical = en.get_clinical("awg")
endometrioid_clinical = clinical.loc[clinical["Histologic_type"] == "Endometrioid"]
serous_clinical = clinical.loc[clinical["Histologic_type"] == "Serous"]

# %%
endometrioid_clinical.head()
# Out:
# Name       Sample_ID Sample_Tumor_Normal Proteomics_Tumor_Normal  \
# Patient_ID
# C3L-00006       S001               Tumor                   Tumor
# C3L-00008       S002               Tumor                   Tumor
# C3L-00032       S003               Tumor                   Tumor
# C3L-00090       S005               Tumor                   Tumor
# C3L-00136       S007               Tumor                   Tumor
#
# Name              Country Histologic_Grade_FIGO Myometrial_invasion_Specify  \
# Patient_ID
# C3L-00006   United States          FIGO grade 1                  under 50 %
# C3L-00008   United States          FIGO grade 1                  under 50 %
# C3L-00032   United States          FIGO grade 2                  under 50 %
# C3L-00090   United States          FIGO grade 2                  under 50 %
# C3L-00136   United States          FIGO grade 1                  under 50 %
#
# Name       Histologic_type Treatment_naive Tumor_purity  \
# Patient_ID
# C3L-00006     Endometrioid             YES       Normal
# C3L-00008     Endometrioid             YES       Normal
# C3L-00032     Endometrioid             YES       Normal
# C3L-00090     Endometrioid             YES       Normal
# C3L-00136     Endometrioid             YES       Normal
#
# Name       Path_Stage_Primary_Tumor-pT  ...   Age Diabetes   Race  \
# Patient_ID                              ...
# C3L-00006               pT1a (FIGO IA)  ...  64.0       No  White
# C3L-00008               pT1a (FIGO IA)  ...  58.0       No  White
# C3L-00032               pT1a (FIGO IA)  ...  50.0      Yes  White
# C3L-00090               pT1a (FIGO IA)  ...  75.0       No  White
# C3L-00136               pT1a (FIGO IA)  ...  50.0       No  White
#
# Name                     Ethnicity  Gender             Tumor_Site  \
# Patient_ID
# C3L-00006   Not-Hispanic or Latino  Female   Anterior endometrium
# C3L-00008   Not-Hispanic or Latino  Female  Posterior endometrium
# C3L-00032   Not-Hispanic or Latino  Female         Other, specify
# C3L-00090   Not-Hispanic or Latino  Female         Other, specify
# C3L-00136   Not-Hispanic or Latino  Female         Other, specify
#
# Name                          Tumor_Site_Other  Tumor_Focality Tumor_Size_cm  \
# Patient_ID
# C3L-00006                                  NaN        Unifocal           2.9
# C3L-00008                                  NaN        Unifocal           3.5
# C3L-00032   Anterior and Posterior endometrium        Unifocal           4.5
# C3L-00090   Anterior and Posterior endometrium        Unifocal           3.5
# C3L-00136   Anterior and Posterior endometrium        Unifocal           4.5
#
# Name       Num_full_term_pregnancies
# Patient_ID
# C3L-00006                          1
# C3L-00008                          1
# C3L-00032                  4 or more
# C3L-00090                  4 or more
# C3L-00136                          3
#
# [5 rows x 27 columns]

# %%
serous_clinical.head()
# Out:
# Name       Sample_ID Sample_Tumor_Normal Proteomics_Tumor_Normal  \
# Patient_ID
# C3L-00098       S006               Tumor                   Tumor
# C3L-00139       S009               Tumor                   Tumor
# C3L-00358       S016               Tumor                   Tumor
# C3L-00963       S041               Tumor                   Tumor
# C3L-01246       S042               Tumor                   Tumor
#
# Name              Country Histologic_Grade_FIGO Myometrial_invasion_Specify  \
# Patient_ID
# C3L-00098   United States                   NaN                  under 50 %
# C3L-00139   United States                   NaN                50 % or more
# C3L-00358   United States                   NaN                50 % or more
# C3L-00963   Other_specify                   NaN                50 % or more
# C3L-01246   Other_specify                   NaN                  under 50 %
#
# Name       Histologic_type Treatment_naive Tumor_purity  \
# Patient_ID
# C3L-00098           Serous             YES       Normal
# C3L-00139           Serous             YES       Normal
# C3L-00358           Serous             YES       Normal
# C3L-00963           Serous             YES       Normal
# C3L-01246           Serous             YES       Normal
#
# Name       Path_Stage_Primary_Tumor-pT  ...   Age Diabetes   Race  \
# Patient_ID                              ...
# C3L-00098               pT1a (FIGO IA)  ...  63.0       No  White
# C3L-00139             pT3a (FIGO IIIA)  ...  83.0       No  White
# C3L-00358               pT1b (FIGO IB)  ...  90.0       No  White
# C3L-00963               pT1b (FIGO IB)  ...  59.0      Yes  White
# C3L-01246               pT1a (FIGO IA)  ...  62.0       No  White
#
# Name                     Ethnicity  Gender             Tumor_Site  \
# Patient_ID
# C3L-00098   Not-Hispanic or Latino  Female         Other, specify
# C3L-00139   Not-Hispanic or Latino  Female         Other, specify
# C3L-00358   Not-Hispanic or Latino  Female         Other, specify
# C3L-00963             Not reported  Female         Other, specify
# C3L-01246             Not reported  Female  Posterior endometrium
#
# Name                               Tumor_Site_Other  Tumor_Focality  \
# Patient_ID
# C3L-00098       Anterior  and Posterior endometrium        Unifocal
# C3L-00139               Both anterior and posterior        Unifocal
# C3L-00358   Both anterior and posterior endometrium        Unifocal
# C3L-00963      along anterior and posterior surface        Unifocal
# C3L-01246                                       NaN        Unifocal
#
# Name       Tumor_Size_cm Num_full_term_pregnancies
# Patient_ID
# C3L-00098            6.0                         2
# C3L-00139            4.0                 4 or more
# C3L-00358            4.5                   Unknown
# C3L-00963            2.6                         1
# C3L-01246            2.3                         1
#
# [5 rows x 27 columns]

# %% [markdown]
# ## How do I export a dataframe to a file?
#
# If you wish to export a dataframe to a file, call the dataframe's built-in `to_csv` method, specifying the path you wish to save to, and the separator you wish to use:

# %%
clinical = en.get_clinical('awg')
clinical.to_csv(path_or_buf="clinical_df.tsv", sep='\t')
